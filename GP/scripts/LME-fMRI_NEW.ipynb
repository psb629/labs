# %%
from pymer4.models import Lmer
# For data manipulation and analysis
import pandas as pd
# For statistics and econometrics
import statsmodels.formula.api as smf
from statsmodels.stats.multitest import multipletests
# For numerical operations
import numpy as np
# For visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Linear mixed effect model using pymer4 or statsmodels

# %%
# Reload the data
df = pd.read_excel('Rew#1_Coef_filtered_new.xlsx')
run_to_time = {'r01': 0, 'r02': 1, 'r03': 2}
df['time'] = df['run'].map(run_to_time)
# df['group'] = pd.Categorical(df['group'], categories=['no_stim', 'DLPFC_cTBS', 'M1_cTBS'], ordered=True)


# Define the ROIs
rois_left = ['laPU', 'laCA', 'lpPU', 'lpCA']
rois_right = ['raPU', 'raCA', 'rpPU', 'rpCA']
rois_PU = ['laPU','raPU','lpPU','rpPU']
rois_CA = ['laCA','raCA','lpCA','rpCA']


# Convert 'run' to numerical values representing the order of time

# Recode the 'group' variable to use 'no_stim' as the baseline level
# data_all_groups['group_recoded'] = pd.Categorical(data_all_groups['group'], 
#                                                   categories=['no_stim', 'DLPFC_cTBS', 'M1_cTBS'], 
#                                                   orde_red=True)


# Define the regions as anterior and posterior
anterior_regions = ['laPU', 'laCA', 'raPU', 'raCA']
posterior_regions = ['lpPU', 'lpCA', 'rpPU', 'rpCA']

# Create a new column 'region' in the data for anterior vs posterior comparision
df["region"] = "anterior"
df.loc[df['roi'].isin(posterior_regions), "region"] = "posterior"

## Make a label for right and left ROIs
df["LR"] = "left"
df.loc[df['roi'].isin(rois_right), "LR"] = "right"

# Define PC for comparing putamen versus caudate nucleus
df["PC"] = "PU"
df.loc[df['roi'].isin(rois_CA), "PC"] = "CA"
# Convert 'region' to categorical
df["region"] = pd.Categorical(df["region"])


# Perform the analysis for each ROI
interaction_results_time_recoded = {}
mixedlm_result = {}
for roi in rois_left + rois_right:
    roi_data = df[df['roi'] == roi].dropna()
    
    # Fit the mixed effects model
#     mixedlm_result = smf.mixedlm("beta ~ time * group", roi_data, groups=roi_data['subj']).fit()
    model = Lmer('beta ~ time * group + (1|subj)',data =roi_data )
# model = smf.mixedlm("beta ~ time * group_recoded", roi_data, groups=roi_data['subj'], re_formula="~time")
    mixedlm_result[roi] = model.fit()
    
    # Get the p-value of the interaction term
    print(mixedlm_result[roi])
#     interaction_results_time_recoded[roi] = {f"time:group_recoded[T.{group}]": p_val for group, p_val in mixedlm_result.pvalues.items() if "group_recoded" in group}

#     print(mixedlm_result.summary())
# Out:
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*group+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 192	 Groups: {'subj': 64.0}
#
# Log-likelihood: -44.934 	 AIC: 105.868
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.068  0.260
# Residual               0.049  0.221
#
# No random effect correlations specified
#
# Fixed effects:
#
#                       Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  \
# (Intercept)              0.601   0.484    0.719  0.060   97.567  10.002
# time                    -0.133  -0.189   -0.077  0.029  125.000  -4.663
# groupDLPFC_cTBS         -0.024  -0.220    0.172  0.100   97.567  -0.244
# groupM1_cTBS             0.005  -0.191    0.201  0.100   97.567   0.048
# time:groupDLPFC_cTBS    -0.083  -0.176    0.010  0.047  125.000  -1.752
# time:groupM1_cTBS        0.052  -0.041    0.145  0.047  125.000   1.103
#
#                       P-val  Sig
# (Intercept)           0.000  ***
# time                  0.000  ***
# groupDLPFC_cTBS       0.808
# groupM1_cTBS          0.962
# time:groupDLPFC_cTBS  0.082    .
# time:groupM1_cTBS     0.272
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*group+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 192	 Groups: {'subj': 64.0}
#
# Log-likelihood: -50.051 	 AIC: 116.102
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.057  0.240
# Residual               0.056  0.236
#
# No random effect correlations specified
#
# Fixed effects:
#
#                       Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  \
# (Intercept)              0.426   0.311    0.541  0.059  106.903   7.240
# time                    -0.087  -0.147   -0.027  0.030  125.000  -2.853
# groupDLPFC_cTBS          0.119  -0.073    0.310  0.098  106.903   1.213
# groupM1_cTBS             0.046  -0.146    0.238  0.098  106.903   0.472
# time:groupDLPFC_cTBS    -0.177  -0.277   -0.078  0.051  125.000  -3.504
# time:groupM1_cTBS        0.012  -0.087    0.112  0.051  125.000   0.242
#
#                       P-val  Sig
# (Intercept)           0.000  ***
# time                  0.005   **
# groupDLPFC_cTBS       0.228
# groupM1_cTBS          0.638
# time:groupDLPFC_cTBS  0.001  ***
# time:groupM1_cTBS     0.809
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*group+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 192	 Groups: {'subj': 64.0}
#
# Log-likelihood: -6.101 	 AIC: 28.203
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.031  0.175
# Residual               0.036  0.191
#
# No random effect correlations specified
#
# Fixed effects:
#
#                       Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  \
# (Intercept)              0.279   0.190    0.367  0.045  113.875   6.178
# time                    -0.105  -0.154   -0.057  0.025  125.000  -4.279
# groupDLPFC_cTBS         -0.007  -0.154    0.140  0.075  113.875  -0.096
# groupM1_cTBS            -0.042  -0.189    0.105  0.075  113.875  -0.564
# time:groupDLPFC_cTBS    -0.004  -0.084    0.077  0.041  125.000  -0.093
# time:groupM1_cTBS        0.069  -0.011    0.150  0.041  125.000   1.694
#
#                       P-val  Sig
# (Intercept)           0.000  ***
# time                  0.000  ***
# groupDLPFC_cTBS       0.924
# groupM1_cTBS          0.574
# time:groupDLPFC_cTBS  0.926
# time:groupM1_cTBS     0.093    .
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*group+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 192	 Groups: {'subj': 64.0}
#
# Log-likelihood: -64.284 	 AIC: 144.568
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.075  0.275
# Residual               0.062  0.250
#
# No random effect correlations specified
#
# Fixed effects:
#
#                       Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  \
# (Intercept)              0.368   0.240    0.496  0.065  101.72   5.647  0.000
# time                    -0.160  -0.223   -0.096  0.032  125.00  -4.950  0.000
# groupDLPFC_cTBS          0.037  -0.176    0.249  0.108  101.72   0.340  0.735
# groupM1_cTBS            -0.017  -0.230    0.195  0.108  101.72  -0.160  0.873
# time:groupDLPFC_cTBS    -0.089  -0.194    0.016  0.054  125.00  -1.666  0.098
# time:groupM1_cTBS        0.062  -0.043    0.167  0.054  125.00   1.150  0.252
#
#                       Sig
# (Intercept)           ***
# time                  ***
# groupDLPFC_cTBS
# groupM1_cTBS
# time:groupDLPFC_cTBS    .
# time:groupM1_cTBS
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*group+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 192	 Groups: {'subj': 64.0}
#
# Log-likelihood: -24.526 	 AIC: 65.052
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.051  0.227
# Residual               0.040  0.200
#
# No random effect correlations specified
#
# Fixed effects:
#
#                       Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  \
# (Intercept)              0.596   0.492    0.700  0.053   99.907  11.221
# time                    -0.093  -0.144   -0.043  0.026  125.000  -3.608
# groupDLPFC_cTBS          0.019  -0.154    0.192  0.088   99.907   0.215
# groupM1_cTBS            -0.013  -0.186    0.160  0.088   99.907  -0.150
# time:groupDLPFC_cTBS    -0.106  -0.190   -0.022  0.043  125.000  -2.473
# time:groupM1_cTBS        0.007  -0.077    0.092  0.043  125.000   0.171
#
#                       P-val  Sig
# (Intercept)           0.000  ***
# time                  0.000  ***
# groupDLPFC_cTBS       0.830
# groupM1_cTBS          0.881
# time:groupDLPFC_cTBS  0.015    *
# time:groupM1_cTBS     0.864
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*group+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 192	 Groups: {'subj': 64.0}
#
# Log-likelihood: -48.060 	 AIC: 112.119
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.056  0.236
# Residual               0.055  0.234
#
# No random effect correlations specified
#
# Fixed effects:
#
#                       Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  \
# (Intercept)              0.478   0.364    0.592  0.058  107.266   8.228
# time                    -0.108  -0.167   -0.049  0.030  125.000  -3.579
# groupDLPFC_cTBS          0.017  -0.172    0.207  0.097  107.266   0.179
# groupM1_cTBS             0.009  -0.181    0.198  0.097  107.266   0.088
# time:groupDLPFC_cTBS    -0.136  -0.234   -0.037  0.050  125.000  -2.707
# time:groupM1_cTBS        0.026  -0.072    0.124  0.050  125.000   0.517
#
#                       P-val  Sig
# (Intercept)           0.000  ***
# time                  0.000  ***
# groupDLPFC_cTBS       0.858
# groupM1_cTBS          0.930
# time:groupDLPFC_cTBS  0.008   **
# time:groupM1_cTBS     0.606
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*group+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 192	 Groups: {'subj': 64.0}
#
# Log-likelihood: 6.155 	 AIC: 3.689
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.031  0.176
# Residual               0.031  0.175
#
# No random effect correlations specified
#
# Fixed effects:
#
#                       Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  \
# (Intercept)              0.325   0.240    0.410  0.043  107.582   7.493
# time                    -0.092  -0.136   -0.047  0.023  125.000  -4.056
# groupDLPFC_cTBS         -0.029  -0.170    0.112  0.072  107.582  -0.405
# groupM1_cTBS            -0.041  -0.183    0.100  0.072  107.582  -0.574
# time:groupDLPFC_cTBS     0.001  -0.072    0.075  0.038  125.000   0.030
# time:groupM1_cTBS        0.048  -0.025    0.122  0.038  125.000   1.290
#
#                       P-val  Sig
# (Intercept)           0.000  ***
# time                  0.000  ***
# groupDLPFC_cTBS       0.687
# groupM1_cTBS          0.567
# time:groupDLPFC_cTBS  0.976
# time:groupM1_cTBS     0.200
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*group+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 192	 Groups: {'subj': 64.0}
#
# Log-likelihood: -49.559 	 AIC: 115.118
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.063  0.251
# Residual               0.054  0.231
#
# No random effect correlations specified
#
# Fixed effects:
#
#                       Estimate  2.5_ci  97.5_ci    SE       DF  T-stat  P-val  \
# (Intercept)              0.339   0.222    0.456  0.06  102.573   5.658  0.000
# time                    -0.132  -0.191   -0.074  0.03  125.000  -4.433  0.000
# groupDLPFC_cTBS          0.067  -0.128    0.262  0.10  102.573   0.675  0.501
# groupM1_cTBS            -0.046  -0.242    0.149  0.10  102.573  -0.466  0.642
# time:groupDLPFC_cTBS    -0.138  -0.235   -0.040  0.05  125.000  -2.771  0.006
# time:groupM1_cTBS        0.061  -0.036    0.159  0.05  125.000   1.231  0.221
#
#                       Sig
# (Intercept)           ***
# time                  ***
# groupDLPFC_cTBS
# groupM1_cTBS
# time:groupDLPFC_cTBS   **
# time:groupM1_cTBS

# %% [markdown]
# ### ANOVA among group difference for the initial fMRI activity (~10 minute)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Subset the data to include only the first run
for roi in rois_left + rois_right:
    df_first_run = df[(df['run'] == 'r01') & (df['roi'] == roi)]  # replace 'r01' with the correct value for the first run in your data

    # Fit the model
    model = ols('beta ~ group', data=df_first_run).fit()

    # Perform the ANOVA
    anova_table = sm.stats.anova_lm(model, typ=2)

    print(anova_table)
# Out:
#             sum_sq    df         F    PR(>F)
# group     0.007092   2.0  0.044343  0.956657
# Residual  4.878059  61.0       NaN       NaN
#             sum_sq    df         F    PR(>F)
# group     0.255806   2.0  1.216573  0.303329
# Residual  6.413166  61.0       NaN       NaN
#             sum_sq    df         F    PR(>F)
# group     0.034784   2.0  0.323626  0.724755
# Residual  3.278172  61.0       NaN       NaN
#             sum_sq    df         F    PR(>F)
# group     0.070531   2.0  0.339899  0.713182
# Residual  6.328969  61.0       NaN       NaN
#             sum_sq    df         F    PR(>F)
# group     0.045067   2.0  0.334716  0.716847
# Residual  4.106603  61.0       NaN       NaN
#             sum_sq    df         F    PR(>F)
# group     0.026174   2.0  0.147608  0.863077
# Residual  5.408274  61.0       NaN       NaN
#             sum_sq    df        F    PR(>F)
# group     0.068982   2.0  0.72749  0.487264
# Residual  2.892069  61.0      NaN       NaN
#             sum_sq    df         F    PR(>F)
# group     0.164995   2.0  0.782798  0.461663
# Residual  6.428663  61.0       NaN       NaN

# %%
df['group'].unique()
# Out:
# array(['baseline', 'M1_cTBS', 'DLPFC_cTBS'], dtype=object)

# %% [markdown]
# ### For each stimulation group, analyze the time dependency

# %%
for group in df['group'].unique():
    model = Lmer('beta ~ time + (1|subj)', data = df[df['group'] == group])
    print(model.fit())
# Out:
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 720	 Groups: {'subj': 30.0}
#
# Log-likelihood: -105.248 	 AIC: 218.496
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.064  0.254
# Residual               0.068  0.260
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.426   0.331    0.522  0.049   32.766   8.736    0.0  ***
# time           -0.114  -0.137   -0.090  0.012  689.000  -9.568    0.0  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 408	 Groups: {'subj': 17.0}
#
# Log-likelihood: 2.523 	 AIC: 2.954
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.055  0.235
# Residual               0.049  0.222
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.414   0.297    0.531  0.060   17.767   6.948    0.0  ***
# time           -0.071  -0.098   -0.045  0.013  390.000  -5.308    0.0  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 408	 Groups: {'subj': 17.0}
#
# Log-likelihood: -19.355 	 AIC: 46.711
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.036  0.191
# Residual               0.056  0.237
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.451   0.354    0.549  0.050   19.019   9.056    0.0  ***
# time           -0.205  -0.233   -0.177  0.014  390.000 -14.303    0.0  ***

# %% [markdown]
# ### For each stimulation group and ROI, analyze the time dependency

# %%
for group in df['group'].unique():
    for roi in rois_left + rois_right:
        model = Lmer('beta ~ time + (1|subj)', data = df[(df['group'] == group) & (df['roi'] == roi)])
        print(model.fit())
# Out:
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 90	 Groups: {'subj': 30.0}
#
# Log-likelihood: -29.812 	 AIC: 67.624
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.087  0.295
# Residual               0.060  0.245
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.601   0.469    0.734  0.068  45.827   8.893    0.0  ***
# time           -0.133  -0.195   -0.071  0.032  59.000  -4.198    0.0  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 90	 Groups: {'subj': 30.0}
#
# Log-likelihood: -22.649 	 AIC: 53.298
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.060  0.246
# Residual               0.055  0.234
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci    SE      DF  T-stat  P-val  Sig
# (Intercept)     0.426   0.309    0.542  0.06  49.767   7.155  0.000  ***
# time           -0.087  -0.146   -0.028  0.03  59.000  -2.872  0.006   **
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 90	 Groups: {'subj': 30.0}
#
# Log-likelihood: -10.946 	 AIC: 29.893
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.032  0.178
# Residual               0.047  0.218
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.279   0.183    0.374  0.049  57.987   5.720    0.0  ***
# time           -0.105  -0.161   -0.050  0.028  59.000  -3.754    0.0  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 90	 Groups: {'subj': 30.0}
#
# Log-likelihood: -40.979 	 AIC: 89.957
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.085  0.292
# Residual               0.085  0.292
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.368   0.226    0.509  0.072  51.284   5.094    0.0  ***
# time           -0.160  -0.233   -0.086  0.038  59.000  -4.230    0.0  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 90	 Groups: {'subj': 30.0}
#
# Log-likelihood: -15.689 	 AIC: 39.378
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.057  0.238
# Residual               0.045  0.213
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.596   0.486    0.706  0.056  47.853  10.618  0.000  ***
# time           -0.093  -0.147   -0.039  0.028  59.000  -3.388  0.001   **
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 90	 Groups: {'subj': 30.0}
#
# Log-likelihood: -28.670 	 AIC: 65.339
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.062  0.250
# Residual               0.065  0.255
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.478   0.356    0.600  0.062  51.995   7.662  0.000  ***
# time           -0.108  -0.173   -0.043  0.033  59.000  -3.276  0.002   **
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 90	 Groups: {'subj': 30.0}
#
# Log-likelihood: -6.474 	 AIC: 20.948
#
# Random effects:
#
#                  Name    Var   Std
# subj      (Intercept)  0.036  0.19
# Residual               0.040  0.20
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.325   0.231    0.419  0.048  52.927   6.754  0.000  ***
# time           -0.092  -0.142   -0.041  0.026  59.000  -3.549  0.001  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 90	 Groups: {'subj': 30.0}
#
# Log-likelihood: -31.873 	 AIC: 71.746
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.060  0.244
# Residual               0.073  0.270
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.339   0.215    0.463  0.063  54.596   5.354    0.0  ***
# time           -0.132  -0.201   -0.064  0.035  59.000  -3.801    0.0  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -4.944 	 AIC: 17.889
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.064  0.253
# Residual               0.033  0.181
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.606   0.463     0.75  0.073  23.257   8.275  0.000  ***
# time           -0.081  -0.142    -0.02  0.031  33.000  -2.596  0.014    *
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -12.994 	 AIC: 33.989
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.077  0.278
# Residual               0.048  0.219
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.472   0.309    0.635  0.083  24.528   5.682  0.000  ***
# time           -0.075  -0.148   -0.001  0.038  33.000  -1.985  0.056    .
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -0.675 	 AIC: 9.349
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.037  0.193
# Residual               0.032  0.178
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.236   0.117    0.356  0.061  26.923   3.871  0.001  ***
# time           -0.036  -0.096    0.024  0.030  33.000  -1.182  0.246
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -7.442 	 AIC: 22.884
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.062  0.250
# Residual               0.038  0.195
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.351   0.205    0.496  0.074  24.395   4.710  0.000  ***
# time           -0.098  -0.164   -0.032  0.033  33.000  -2.923  0.006   **
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -2.538 	 AIC: 13.077
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.059  0.244
# Residual               0.030  0.172
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.583   0.445    0.721  0.070  23.046   8.299  0.000  ***
# time           -0.086  -0.144   -0.028  0.029  33.000  -2.914  0.006   **
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -6.390 	 AIC: 20.780
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.062  0.249
# Residual               0.036  0.190
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.487   0.342    0.631  0.074  24.014   6.605  0.000  ***
# time           -0.082  -0.146   -0.018  0.033  33.000  -2.522  0.017    *
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: 12.040 	 AIC: -16.081
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.035  0.186
# Residual               0.016  0.126
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.283   0.179    0.388  0.053  22.544   5.334  0.000  ***
# time           -0.043  -0.086   -0.001  0.022  33.000  -1.996  0.054    .
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -4.614 	 AIC: 17.227
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.064  0.254
# Residual               0.032  0.179
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.293   0.149    0.436  0.073  23.057   3.994  0.001  ***
# time           -0.071  -0.132   -0.011  0.031  33.000  -2.318  0.027    *
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -6.939 	 AIC: 21.878
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.037  0.192
# Residual               0.044  0.211
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.577   0.448    0.706  0.066  30.041   8.758    0.0  ***
# time           -0.216  -0.287   -0.145  0.036  33.000  -5.980    0.0  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -13.418 	 AIC: 34.836
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.032  0.179
# Residual               0.065  0.254
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.545   0.405    0.684  0.071  34.964   7.664    0.0  ***
# time           -0.264  -0.350   -0.179  0.044  33.000  -6.066    0.0  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: 9.249 	 AIC: -10.498
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.022  0.149
# Residual               0.022  0.148
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.272   0.176    0.367  0.049  28.177   5.571    0.0  ***
# time           -0.109  -0.159   -0.060  0.025  33.000  -4.312    0.0  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -11.284 	 AIC: 30.569
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.070  0.265
# Residual               0.045  0.213
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.405   0.249    0.561  0.080  24.782   5.080    0.0  ***
# time           -0.249  -0.320   -0.177  0.036  33.000  -6.817    0.0  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -4.895 	 AIC: 17.790
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.034  0.183
# Residual               0.041  0.202
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.615   0.492    0.739  0.063  30.145   9.751    0.0  ***
# time           -0.199  -0.267   -0.131  0.035  33.000  -5.745    0.0  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -10.812 	 AIC: 29.623
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.037  0.192
# Residual               0.054  0.233
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci    SE      DF  T-stat  P-val  Sig
# (Intercept)     0.495   0.359    0.632  0.07  31.913   7.118    0.0  ***
# time           -0.244  -0.322   -0.165  0.04  33.000  -6.097    0.0  ***
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: 5.537 	 AIC: -3.073
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.017  0.132
# Residual               0.029  0.169
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.296   0.199    0.392  0.049  32.923   6.001  0.000  ***
# time           -0.090  -0.147   -0.034  0.029  33.000  -3.122  0.004   **
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 51	 Groups: {'subj': 17.0}
#
# Log-likelihood: -9.078 	 AIC: 26.157
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.068  0.260
# Residual               0.041  0.201
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  Sig
# (Intercept)     0.406   0.255    0.558  0.077  24.237   5.255    0.0  ***
# time           -0.270  -0.338   -0.202  0.035  33.000  -7.823    0.0  ***

# %% [markdown]
# ### More analyses

# %%
df_CA = df[df['roi'].str.endswith('CA')]
df_PU = df[df['roi'].str.endswith('PU')]
df_DLPFC_cTBS = df[df['group']=='DLPFC_cTBS']
df_baseline = df[df['group']=='no_stim']
df_M1_cTBS = df[df['group']=='M1_cTBS']
df_DLPFC_cTBS_CA = df[(df['roi'].str.endswith('CA')) & (df['group']=='DLPFC_cTBS')]
df_DLPFC_cTBS_PU = df[(df['roi'].str.endswith('PU')) & (df['group']=='DLPFC_cTBS')]
df_DLPFC_cTBS_LCA = df[(df['roi'].str.endswith('CA')) & (df['group']=='DLPFC_cTBS') & (df['LR']=='left')]
df_DLPFC_cTBS_Ant = df[(df['group']=='DLPFC_cTBS') & (df['region']=='anterior')]

# %%
model = Lmer('beta ~ time * PC + (1|subj)',data = df_DLPFC_cTBS_Ant)
print(model.fit())
# Out:
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*PC+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 204	 Groups: {'subj': 17.0}
#
# Log-likelihood: -3.133 	 AIC: 18.266
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.040  0.200
# Residual               0.045  0.213
#
# No random effect correlations specified
#
# Fixed effects:
#
#              Estimate  2.5_ci  97.5_ci     SE       DF  T-stat  P-val  Sig
# (Intercept)     0.520   0.404    0.635  0.059   28.626   8.815  0.000  ***
# time           -0.254  -0.305   -0.203  0.026  184.000  -9.828  0.000  ***
# PCPU            0.076  -0.016    0.169  0.047  184.000   1.615  0.108
# time:PCPU       0.046  -0.025    0.118  0.037  184.000   1.268  0.206

# %%
model = Lmer('beta ~ time * region + (1|subj)',data =df_DLPFC_cTBS)
print(model.fit())
# Out:
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*region+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 408	 Groups: {'subj': 17.0}
#
# Log-likelihood: 2.423 	 AIC: 7.153
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.037  0.192
# Residual               0.049  0.221
#
# No random effect correlations specified
#
# Fixed effects:
#
#                       Estimate  2.5_ci  97.5_ci     SE      DF  T-stat  P-val  \
# (Intercept)              0.558   0.455    0.661  0.053   23.41  10.627  0.000
# time                    -0.231  -0.268   -0.194  0.019  388.00 -12.172  0.000
# regionposterior         -0.213  -0.281   -0.146  0.035  388.00  -6.164  0.000
# time:regionposterior     0.051  -0.001    0.104  0.027  388.00   1.911  0.057
#
#                       Sig
# (Intercept)           ***
# time                  ***
# regionposterior       ***
# time:regionposterior    .

# %%
model = Lmer('beta ~ time * region * group + (1|subj)',data =df)
print(model.fit())
# Out:
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*region*group+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 1536	 Groups: {'subj': 64.0}
#
# Log-likelihood: 5.916 	 AIC: 16.168
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.055  0.235
# Residual               0.049  0.221
#
# No random effect correlations specified
#
# Fixed effects:
#
#                                    Estimate  2.5_ci  97.5_ci     SE        DF  \
# (Intercept)                           0.558   0.437    0.679  0.062    79.516
# time                                 -0.231  -0.268   -0.194  0.019  1463.000
# regionposterior                      -0.213  -0.281   -0.146  0.035  1463.000
# groupM1_cTBS                         -0.021  -0.193    0.151  0.088    79.516
# groupno_stim                         -0.033  -0.185    0.119  0.078    79.516
# time:regionposterior                  0.051  -0.001    0.104  0.027  1463.000
# time:groupM1_cTBS                     0.150   0.098    0.203  0.027  1463.000
# time:groupno_stim                     0.126   0.079    0.172  0.024  1463.000
# regionposterior:groupM1_cTBS         -0.033  -0.128    0.063  0.049  1463.000
# regionposterior:groupno_stim          0.016  -0.069    0.101  0.043  1463.000
# time:regionposterior:groupM1_cTBS    -0.033  -0.107    0.042  0.038  1463.000
# time:regionposterior:groupno_stim    -0.068  -0.134   -0.003  0.034  1463.000
#
#                                    T-stat  P-val  Sig
# (Intercept)                         9.006  0.000  ***
# time                              -12.196  0.000  ***
# regionposterior                    -6.176  0.000  ***
# groupM1_cTBS                       -0.241  0.810
# groupno_stim                       -0.421  0.675
# time:regionposterior                1.914  0.056    .
# time:groupM1_cTBS                   5.606  0.000  ***
# time:groupno_stim                   5.302  0.000  ***
# regionposterior:groupM1_cTBS       -0.668  0.504
# regionposterior:groupno_stim        0.364  0.716
# time:regionposterior:groupM1_cTBS  -0.859  0.390
# time:regionposterior:groupno_stim  -2.036  0.042    *

# %%
model = Lmer('beta ~ time * region * group + (1|subj)',data =df_PU )
print(model.fit())
# Out:
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*region*group+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 768	 Groups: {'subj': 64.0}
#
# Log-likelihood: 60.656 	 AIC: -93.311
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.047  0.217
# Residual               0.037  0.192
#
# No random effect correlations specified
#
# Fixed effects:
#
#                                    Estimate  2.5_ci  97.5_ci     SE       DF  \
# (Intercept)                           0.596   0.477    0.715  0.061   94.097
# time                                 -0.208  -0.253   -0.162  0.023  695.000
# regionposterior                      -0.313  -0.396   -0.229  0.043  695.000
# groupM1_cTBS                         -0.002  -0.170    0.167  0.086   94.097
# groupno_stim                          0.003  -0.146    0.152  0.076   94.097
# time:regionposterior                  0.108   0.043    0.173  0.033  695.000
# time:groupM1_cTBS                     0.124   0.060    0.189  0.033  695.000
# time:groupno_stim                     0.095   0.037    0.152  0.029  695.000
# regionposterior:groupM1_cTBS         -0.022  -0.140    0.096  0.060  695.000
# regionposterior:groupno_stim          0.015  -0.089    0.120  0.053  695.000
# time:regionposterior:groupM1_cTBS    -0.064  -0.156    0.027  0.047  695.000
# time:regionposterior:groupno_stim    -0.093  -0.174   -0.012  0.041  695.000
#
#                                    T-stat  P-val  Sig
# (Intercept)                         9.822  0.000  ***
# time                               -8.906  0.000  ***
# regionposterior                    -7.338  0.000  ***
# groupM1_cTBS                       -0.018  0.986
# groupno_stim                        0.035  0.972
# time:regionposterior                3.270  0.001   **
# time:groupM1_cTBS                   3.773  0.000  ***
# time:groupno_stim                   3.241  0.001   **
# regionposterior:groupM1_cTBS       -0.367  0.713
# regionposterior:groupno_stim        0.290  0.772
# time:regionposterior:groupM1_cTBS  -1.376  0.169
# time:regionposterior:groupno_stim  -2.259  0.024    *

# %%
model = Lmer('beta ~ time * region * group + (1|subj)',data =df_CA )
print(model.fit())
# Out:
# Linear mixed model fit by REML [’lmerMod’]
# Formula: beta~time*region*group+(1|subj)
#
# Family: gaussian	 Inference: parametric
#
# Number of observations: 768	 Groups: {'subj': 64.0}
#
# Log-likelihood: -65.145 	 AIC: 158.289
#
# Random effects:
#
#                  Name    Var    Std
# subj      (Intercept)  0.067  0.260
# Residual               0.052  0.227
#
# No random effect correlations specified
#
# Fixed effects:
#
#                                    Estimate  2.5_ci  97.5_ci     SE       DF  \
# (Intercept)                           0.520   0.378    0.662  0.072   93.259
# time                                 -0.254  -0.308   -0.200  0.028  695.000
# regionposterior                      -0.114  -0.213   -0.016  0.050  695.000
# groupM1_cTBS                         -0.041  -0.241    0.160  0.102   93.259
# groupno_stim                         -0.068  -0.245    0.109  0.090   93.259
# time:regionposterior                 -0.005  -0.082    0.071  0.039  695.000
# time:groupM1_cTBS                     0.176   0.099    0.252  0.039  695.000
# time:groupno_stim                     0.157   0.089    0.224  0.034  695.000
# regionposterior:groupM1_cTBS         -0.043  -0.182    0.096  0.071  695.000
# regionposterior:groupno_stim          0.016  -0.107    0.139  0.063  695.000
# time:regionposterior:groupM1_cTBS    -0.001  -0.109    0.107  0.055  695.000
# time:regionposterior:groupno_stim    -0.043  -0.139    0.052  0.049  695.000
#
#                                    T-stat  P-val  Sig
# (Intercept)                         7.191  0.000  ***
# time                               -9.232  0.000  ***
# regionposterior                    -2.278  0.023    *
# groupM1_cTBS                       -0.398  0.692
# groupno_stim                       -0.751  0.454
# time:regionposterior               -0.138  0.890
# time:groupM1_cTBS                   4.515  0.000  ***
# time:groupno_stim                   4.547  0.000  ***
# regionposterior:groupM1_cTBS       -0.608  0.543
# regionposterior:groupno_stim        0.254  0.800
# time:regionposterior:groupM1_cTBS  -0.016  0.988
# time:regionposterior:groupno_stim  -0.886  0.376

# %%
# model = smf.mixedlm("beta ~ time * group", data_all_groups, groups=data_all_groups["subj"])
model = smf.mixedlm("beta ~ group * time", df, groups=df["subj"])

result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#               Mixed Linear Model Regression Results
# ==================================================================
# Model:                 MixedLM    Dependent Variable:    beta
# No. Observations:      1536       Method:                REML
# No. Groups:            64         Scale:                 0.0598
# Min. group size:       24         Log-Likelihood:        -129.5079
# Max. group size:       24         Converged:             Yes
# Mean group size:       24.0
# ------------------------------------------------------------------
#                        Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ------------------------------------------------------------------
# Intercept               0.451    0.060   7.541 0.000  0.334  0.569
# group[T.M1_cTBS]       -0.037    0.085  -0.442 0.658 -0.203  0.128
# group[T.baseline]      -0.025    0.075  -0.331 0.741 -0.172  0.122
# time                   -0.205    0.015 -13.847 0.000 -0.234 -0.176
# group[T.M1_cTBS]:time   0.134    0.021   6.383 0.000  0.093  0.175
# group[T.baseline]:time  0.092    0.019   4.932 0.000  0.055  0.128
# Group Var               0.055    0.043
# ==================================================================
#
# """
